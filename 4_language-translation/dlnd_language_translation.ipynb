# %% [markdown]
# # 语言翻译
#
# 在此项目中，你将了解神经网络机器翻译这一领域。你将用由英语和法语语句组成的数据集，训练一个序列到序列模型（sequence to sequence model），该模型能够将新的英语句子翻译成法语。
#
# ## 获取数据
#
# 因为将整个英语语言内容翻译成法语需要大量训练时间，所以我们提供了一小部分的英语语料库。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## 探索数据
#
# 研究 view_sentence_range，查看并熟悉该数据的不同部分。

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## 实现预处理函数
#
# ### 文本到单词 id
#
# 和之前的 RNN 一样，你必须首先将文本转换为数字，这样计算机才能读懂。在函数 `text_to_ids()` 中，你需要将单词中的 `source_text` 和 `target_text` 转为 id。但是，你需要在 `target_text` 中每个句子的末尾，添加 `<EOS>` 单词 id。这样可以帮助神经网络预测句子应该在什么地方结束。
#
#
# 你可以通过以下代码获取  `<EOS> ` 单词ID：
#
# ```python
# target_vocab_to_int['<EOS>']
# ```
#
# 你可以使用 `source_vocab_to_int` 和 `target_vocab_to_int` 获得其他单词 id。

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_words = [sentence.split() for sentence in source_text.split('\n')]
    target_words = [sentence.split() for sentence in target_text.split('\n')]
    
    assert(len(source_words) == len(target_words))
    
    source_ids = []
    target_ids = []
    for ii in range(len(source_words)):
        id_text = [source_vocab_to_int[word] for word in source_words[ii]]
        source_ids.append(id_text)
        id_text = [target_vocab_to_int[word] for word in target_words[ii]]
        id_text.append(target_vocab_to_int['<EOS>'])
        target_ids.append(id_text)
        
    return source_ids, target_ids
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### 预处理所有数据并保存
#
# 运行以下代码单元，预处理所有数据，并保存到文件中。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，可以从这里继续。预处理的数据已保存到磁盘上。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### 检查 TensorFlow 版本，确认可访问 GPU
#
# 这一检查步骤，可以确保你使用的是正确版本的 TensorFlow，并且能够访问 GPU。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.1
# Default GPU Device: /gpu:0

# %% [markdown]
# ## 构建神经网络
#
# 你将通过实现以下函数，构建出要构建一个序列到序列模型所需的组件：
#
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### 输入
#
# 实现 `model_inputs()` 函数，为神经网络创建 TF 占位符。该函数应该创建以下占位符：
#
# - 名为 “input” 的输入文本占位符，并使用 TF Placeholder 名称参数（等级（Rank）为 2）。
# - 目标占位符（等级为 2）。
# - 学习速率占位符（等级为 0）。
# - 名为 “keep_prob” 的保留率占位符，并使用 TF Placeholder 名称参数（等级为 0）。
#
# 在以下元祖（tuple）中返回占位符：（输入、目标、学习速率、保留率）

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, [None, None], "input")
    targets = tf.placeholder(tf.int32, [None, None], "targets")
    learning_rate  = tf.placeholder(tf.float32, name = "learning_rate")
    keep_prob = tf.placeholder(tf.float32, name = "keep_prob")
    return inputs, targets, learning_rate, keep_prob

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### 处理解码输入
#
# 使用 TensorFlow 实现 `process_decoding_input`，以便删掉 `target_data` 中每个批次的最后一个单词 ID，并将 GO ID 放到每个批次的开头。

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    slice_tensor = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    go_tensor = tf.fill([batch_size, 1], target_vocab_to_int['<GO>'])
    idx_tensor = tf.concat([go_tensor, slice_tensor], 1)
    
    return idx_tensor

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### 编码
#
# 实现 `encoding_layer()`，以使用 [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn) 创建编码器 RNN 层级。

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    # TODO: Implement Function
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob = keep_prob)
    cell = tf.contrib.rnn.MultiRNNCell([drop]*num_layers)

    _,state = tf.nn.dynamic_rnn(cell, rnn_inputs, dtype = tf.float32)
    
    return state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### 解码 - 训练
#
# 使用 [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) 和 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 创建训练分对数（training logits）。将 `output_fn` 应用到 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 输出上。

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # TODO: Implement Function
    dynamic_fn_train = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    logits,_,_ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, dynamic_fn_train, dec_embed_input,sequence_length, \
                                                    scope = decoding_scope)
    
    
    return output_fn(logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### 解码 - 推论
#
# 使用 [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) 和 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 创建推论分对数（inference logits）。

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    dynamic_fn_train = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn, encoder_state, dec_embeddings,\
                                                                     start_of_sequence_id, end_of_sequence_id, \
                                                                      maximum_length, vocab_size)
    logits,_,_ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, dynamic_fn_train, scope = decoding_scope)
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### 构建解码层级
#
# 实现 `decoding_layer()` 以创建解码器 RNN 层级。
#
# - 使用 `rnn_size` 和 `num_layers` 创建解码 RNN 单元。
# - 使用 [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) 创建输出函数，将输入，也就是分对数转换为类分对数（class logits）。
# - 使用 `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` 函数获取训练分对数。
# - 使用 `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` 函数获取推论分对数。
#
# 注意：你将需要使用 [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) 在训练和推论分对数间分享变量。

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    dec_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size)] * num_layers)
    output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
    
    with tf.variable_scope("decoding") as decoding_scope:
        train_logits = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length,
                                     decoding_scope, output_fn, keep_prob)

        decoding_scope.reuse_variables()
        infer_logits = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, target_vocab_to_int["<GO>"],\
                                           target_vocab_to_int["<EOS>"], sequence_length, vocab_size, decoding_scope, \
                                            output_fn, keep_prob)
    
    
    return train_logits, infer_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### 构建神经网络
#
# 应用你在上方实现的函数，以：
#
# - 向编码器的输入数据应用嵌入。
# - 使用 `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)` 编码输入。
# - 使用 `process_decoding_input(target_data, target_vocab_to_int, batch_size)` 函数处理目标数据。
# - 向解码器的目标数据应用嵌入。
# - 使用 `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)` 解码编码的输入数据。

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    encode_embeding = tf.Variable(tf.random_uniform((source_vocab_size, dec_embedding_size), -1, 1))
    encode_embeded = tf.nn.embedding_lookup(encode_embeding, input_data)
    encode_state = encoding_layer(encode_embeded, rnn_size, num_layers, keep_prob)
    
    target_data = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    decode_embeding = tf.Variable(tf.random_uniform((target_vocab_size, dec_embedding_size), -1, 1))
    decode_embeded = tf.nn.embedding_lookup(decode_embeding, target_data)
    training_logits, inference_logits = decoding_layer(decode_embeded, decode_embeding, encode_state, target_vocab_size, \
                                                       sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)
    
    return training_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## 训练神经网络
#
# ### 超参数
#
# 调试以下参数：
#
# - 将 `epochs` 设为 epoch 次数。
# - 将 `batch_size` 设为批次大小。
# - 将 `rnn_size` 设为 RNN 的大小。
# - 将 `num_layers` 设为层级数量。
# - 将 `encoding_embedding_size` 设为编码器嵌入大小。
# - 将 `decoding_embedding_size` 设为解码器嵌入大小
# - 将 `learning_rate` 设为训练速率。
# - 将 `keep_probability` 设为丢弃保留率（Dropout keep probability）。

# %%
# Number of Epochs
epochs = 3
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 512
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 256
decoding_embedding_size = 256
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 0.7

# %% [markdown]
# ### 构建图表
#
# 使用你实现的神经网络构建图表。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### 训练
#
# 利用预处理的数据训练神经网络。如果很难获得低损失值，请访问我们的论坛，看看其他人是否遇到了相同的问题。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/538 - Train Accuracy:  0.208, Validation Accuracy:  0.275, Loss:  5.867
# Epoch   0 Batch    1/538 - Train Accuracy:  0.169, Validation Accuracy:  0.238, Loss:  4.144
# Epoch   0 Batch    2/538 - Train Accuracy:  0.140, Validation Accuracy:  0.218, Loss:  6.301
# Epoch   0 Batch    3/538 - Train Accuracy:  0.123, Validation Accuracy:  0.204, Loss:  4.949
# Epoch   0 Batch    4/538 - Train Accuracy:  0.237, Validation Accuracy:  0.316, Loss:  4.161
# Epoch   0 Batch    5/538 - Train Accuracy:  0.263, Validation Accuracy:  0.316, Loss:  3.620
# Epoch   0 Batch    6/538 - Train Accuracy:  0.268, Validation Accuracy:  0.316, Loss:  3.563
# Epoch   0 Batch    7/538 - Train Accuracy:  0.245, Validation Accuracy:  0.316, Loss:  3.488
# Epoch   0 Batch    8/538 - Train Accuracy:  0.244, Validation Accuracy:  0.316, Loss:  3.311
# Epoch   0 Batch    9/538 - Train Accuracy:  0.176, Validation Accuracy:  0.244, Loss:  3.100
# Epoch   0 Batch   10/538 - Train Accuracy:  0.249, Validation Accuracy:  0.319, Loss:  3.076
# Epoch   0 Batch   11/538 - Train Accuracy:  0.182, Validation Accuracy:  0.253, Loss:  3.144
# Epoch   0 Batch   12/538 - Train Accuracy:  0.178, Validation Accuracy:  0.244, Loss:  3.060
# Epoch   0 Batch   13/538 - Train Accuracy:  0.207, Validation Accuracy:  0.241, Loss:  2.761
# Epoch   0 Batch   14/538 - Train Accuracy:  0.178, Validation Accuracy:  0.244, Loss:  2.812
# Epoch   0 Batch   15/538 - Train Accuracy:  0.207, Validation Accuracy:  0.241, Loss:  2.595
# Epoch   0 Batch   16/538 - Train Accuracy:  0.357, Validation Accuracy:  0.390, Loss:  2.493
# Epoch   0 Batch   17/538 - Train Accuracy:  0.200, Validation Accuracy:  0.271, Loss:  2.478
# Epoch   0 Batch   18/538 - Train Accuracy:  0.268, Validation Accuracy:  0.331, Loss:  2.407
# Epoch   0 Batch   19/538 - Train Accuracy:  0.262, Validation Accuracy:  0.335, Loss:  2.271
# Epoch   0 Batch   20/538 - Train Accuracy:  0.310, Validation Accuracy:  0.347, Loss:  2.029
# Epoch   0 Batch   21/538 - Train Accuracy:  0.250, Validation Accuracy:  0.351, Loss:  2.073
# Epoch   0 Batch   22/538 - Train Accuracy:  0.301, Validation Accuracy:  0.365, Loss:  1.937
# Epoch   0 Batch   23/538 - Train Accuracy:  0.310, Validation Accuracy:  0.377, Loss:  1.832
# Epoch   0 Batch   24/538 - Train Accuracy:  0.328, Validation Accuracy:  0.362, Loss:  1.721
# Epoch   0 Batch   25/538 - Train Accuracy:  0.265, Validation Accuracy:  0.337, Loss:  1.661
# Epoch   0 Batch   26/538 - Train Accuracy:  0.271, Validation Accuracy:  0.331, Loss:  1.601
# Epoch   0 Batch   27/538 - Train Accuracy:  0.277, Validation Accuracy:  0.324, Loss:  1.493
# Epoch   0 Batch   28/538 - Train Accuracy:  0.328, Validation Accuracy:  0.327, Loss:  1.306
# Epoch   0 Batch   29/538 - Train Accuracy:  0.318, Validation Accuracy:  0.319, Loss:  1.356
# Epoch   0 Batch   30/538 - Train Accuracy:  0.267, Validation Accuracy:  0.319, Loss:  1.368
# Epoch   0 Batch   31/538 - Train Accuracy:  0.289, Validation Accuracy:  0.323, Loss:  1.230
# Epoch   0 Batch   32/538 - Train Accuracy:  0.305, Validation Accuracy:  0.324, Loss:  1.199
# Epoch   0 Batch   33/538 - Train Accuracy:  0.322, Validation Accuracy:  0.348, Loss:  1.196
# Epoch   0 Batch   34/538 - Train Accuracy:  0.301, Validation Accuracy:  0.378, Loss:  1.226
# Epoch   0 Batch   35/538 - Train Accuracy:  0.273, Validation Accuracy:  0.326, Loss:  1.145
# Epoch   0 Batch   36/538 - Train Accuracy:  0.298, Validation Accuracy:  0.326, Loss:  1.098
# Epoch   0 Batch   37/538 - Train Accuracy:  0.304, Validation Accuracy:  0.341, Loss:  1.098
# Epoch   0 Batch   38/538 - Train Accuracy:  0.283, Validation Accuracy:  0.335, Loss:  1.093
# Epoch   0 Batch   39/538 - Train Accuracy:  0.351, Validation Accuracy:  0.424, Loss:  1.099
# Epoch   0 Batch   40/538 - Train Accuracy:  0.366, Validation Accuracy:  0.344, Loss:  0.945
# Epoch   0 Batch   41/538 - Train Accuracy:  0.289, Validation Accuracy:  0.337, Loss:  1.049
# Epoch   0 Batch   42/538 - Train Accuracy:  0.365, Validation Accuracy:  0.423, Loss:  1.022
# Epoch   0 Batch   43/538 - Train Accuracy:  0.347, Validation Accuracy:  0.416, Loss:  1.061
# Epoch   0 Batch   44/538 - Train Accuracy:  0.324, Validation Accuracy:  0.415, Loss:  1.037
# Epoch   0 Batch   45/538 - Train Accuracy:  0.314, Validation Accuracy:  0.338, Loss:  0.957
# Epoch   0 Batch   46/538 - Train Accuracy:  0.275, Validation Accuracy:  0.349, Loss:  0.972
# Epoch   0 Batch   47/538 - Train Accuracy:  0.384, Validation Accuracy:  0.428, Loss:  0.973
# Epoch   0 Batch   48/538 - Train Accuracy:  0.383, Validation Accuracy:  0.427, Loss:  0.935
# Epoch   0 Batch   49/538 - Train Accuracy:  0.397, Validation Accuracy:  0.458, Loss:  0.989
# Epoch   0 Batch   50/538 - Train Accuracy:  0.396, Validation Accuracy:  0.439, Loss:  0.954
# Epoch   0 Batch   51/538 - Train Accuracy:  0.331, Validation Accuracy:  0.433, Loss:  0.981
# Epoch   0 Batch   52/538 - Train Accuracy:  0.395, Validation Accuracy:  0.444, Loss:  0.959
# Epoch   0 Batch   53/538 - Train Accuracy:  0.452, Validation Accuracy:  0.456, Loss:  0.848
# Epoch   0 Batch   54/538 - Train Accuracy:  0.399, Validation Accuracy:  0.450, Loss:  0.901
# Epoch   0 Batch   55/538 - Train Accuracy:  0.417, Validation Accuracy:  0.475, Loss:  0.922
# Epoch   0 Batch   56/538 - Train Accuracy:  0.428, Validation Accuracy:  0.460, Loss:  0.856
# Epoch   0 Batch   57/538 - Train Accuracy:  0.379, Validation Accuracy:  0.457, Loss:  0.913
# Epoch   0 Batch   58/538 - Train Accuracy:  0.379, Validation Accuracy:  0.461, Loss:  0.889
# Epoch   0 Batch   59/538 - Train Accuracy:  0.367, Validation Accuracy:  0.445, Loss:  0.885
# Epoch   0 Batch   60/538 - Train Accuracy:  0.400, Validation Accuracy:  0.443, Loss:  0.848
# Epoch   0 Batch   61/538 - Train Accuracy:  0.400, Validation Accuracy:  0.448, Loss:  0.855
# Epoch   0 Batch   62/538 - Train Accuracy:  0.420, Validation Accuracy:  0.453, Loss:  0.795
# Epoch   0 Batch   63/538 - Train Accuracy:  0.462, Validation Accuracy:  0.470, Loss:  0.791
# Epoch   0 Batch   64/538 - Train Accuracy:  0.403, Validation Accuracy:  0.434, Loss:  0.790
# Epoch   0 Batch   65/538 - Train Accuracy:  0.342, Validation Accuracy:  0.418, Loss:  0.848
# Epoch   0 Batch   66/538 - Train Accuracy:  0.419, Validation Accuracy:  0.435, Loss:  0.772
# Epoch   0 Batch   67/538 - Train Accuracy:  0.433, Validation Accuracy:  0.484, Loss:  0.795
# Epoch   0 Batch   68/538 - Train Accuracy:  0.470, Validation Accuracy:  0.482, Loss:  0.760
# Epoch   0 Batch   69/538 - Train Accuracy:  0.416, Validation Accuracy:  0.479, Loss:  0.806
# Epoch   0 Batch   70/538 - Train Accuracy:  0.435, Validation Accuracy:  0.483, Loss:  0.766
# Epoch   0 Batch   71/538 - Train Accuracy:  0.415, Validation Accuracy:  0.467, Loss:  0.811
# Epoch   0 Batch   72/538 - Train Accuracy:  0.475, Validation Accuracy:  0.470, Loss:  0.787
# Epoch   0 Batch   73/538 - Train Accuracy:  0.422, Validation Accuracy:  0.481, Loss:  0.790
# Epoch   0 Batch   74/538 - Train Accuracy:  0.473, Validation Accuracy:  0.506, Loss:  0.742
# Epoch   0 Batch   75/538 - Train Accuracy:  0.485, Validation Accuracy:  0.500, Loss:  0.731
# Epoch   0 Batch   76/538 - Train Accuracy:  0.431, Validation Accuracy:  0.501, Loss:  0.782
# Epoch   0 Batch   77/538 - Train Accuracy:  0.405, Validation Accuracy:  0.479, Loss:  0.764
# Epoch   0 Batch   78/538 - Train Accuracy:  0.444, Validation Accuracy:  0.491, Loss:  0.740
# Epoch   0 Batch   79/538 - Train Accuracy:  0.463, Validation Accuracy:  0.505, Loss:  0.707
# Epoch   0 Batch   80/538 - Train Accuracy:  0.457, Validation Accuracy:  0.514, Loss:  0.777
# Epoch   0 Batch   81/538 - Train Accuracy:  0.452, Validation Accuracy:  0.511, Loss:  0.755
# Epoch   0 Batch   82/538 - Train Accuracy:  0.432, Validation Accuracy:  0.489, Loss:  0.758
# Epoch   0 Batch   83/538 - Train Accuracy:  0.440, Validation Accuracy:  0.490, Loss:  0.765
# Epoch   0 Batch   84/538 - Train Accuracy:  0.450, Validation Accuracy:  0.481, Loss:  0.736
# Epoch   0 Batch   85/538 - Train Accuracy:  0.453, Validation Accuracy:  0.457, Loss:  0.672
# Epoch   0 Batch   86/538 - Train Accuracy:  0.471, Validation Accuracy:  0.510, Loss:  0.736
# Epoch   0 Batch   87/538 - Train Accuracy:  0.479, Validation Accuracy:  0.490, Loss:  0.728
# Epoch   0 Batch   88/538 - Train Accuracy:  0.496, Validation Accuracy:  0.490, Loss:  0.724
# Epoch   0 Batch   89/538 - Train Accuracy:  0.479, Validation Accuracy:  0.513, Loss:  0.723
# Epoch   0 Batch   90/538 - Train Accuracy:  0.479, Validation Accuracy:  0.504, Loss:  0.705
# Epoch   0 Batch   91/538 - Train Accuracy:  0.474, Validation Accuracy:  0.523, Loss:  0.712
# Epoch   0 Batch   92/538 - Train Accuracy:  0.462, Validation Accuracy:  0.512, Loss:  0.706
# Epoch   0 Batch   93/538 - Train Accuracy:  0.463, Validation Accuracy:  0.507, Loss:  0.713
# Epoch   0 Batch   94/538 - Train Accuracy:  0.464, Validation Accuracy:  0.507, Loss:  0.689
# Epoch   0 Batch   95/538 - Train Accuracy:  0.533, Validation Accuracy:  0.511, Loss:  0.629
# Epoch   0 Batch   96/538 - Train Accuracy:  0.505, Validation Accuracy:  0.510, Loss:  0.645
# Epoch   0 Batch   97/538 - Train Accuracy:  0.497, Validation Accuracy:  0.529, Loss:  0.688
# Epoch   0 Batch   98/538 - Train Accuracy:  0.515, Validation Accuracy:  0.528, Loss:  0.648
# Epoch   0 Batch   99/538 - Train Accuracy:  0.421, Validation Accuracy:  0.488, Loss:  0.694
# Epoch   0 Batch  100/538 - Train Accuracy:  0.521, Validation Accuracy:  0.528, Loss:  0.663
# Epoch   0 Batch  101/538 - Train Accuracy:  0.461, Validation Accuracy:  0.507, Loss:  0.680
# Epoch   0 Batch  102/538 - Train Accuracy:  0.466, Validation Accuracy:  0.506, Loss:  0.675
# Epoch   0 Batch  103/538 - Train Accuracy:  0.454, Validation Accuracy:  0.481, Loss:  0.656
# Epoch   0 Batch  104/538 - Train Accuracy:  0.476, Validation Accuracy:  0.498, Loss:  0.642
# Epoch   0 Batch  105/538 - Train Accuracy:  0.469, Validation Accuracy:  0.525, Loss:  0.640
# Epoch   0 Batch  106/538 - Train Accuracy:  0.520, Validation Accuracy:  0.545, Loss:  0.644
# Epoch   0 Batch  107/538 - Train Accuracy:  0.482, Validation Accuracy:  0.537, Loss:  0.658
# Epoch   0 Batch  108/538 - Train Accuracy:  0.500, Validation Accuracy:  0.515, Loss:  0.661
# Epoch   0 Batch  109/538 - Train Accuracy:  0.541, Validation Accuracy:  0.547, Loss:  0.637
# Epoch   0 Batch  110/538 - Train Accuracy:  0.488, Validation Accuracy:  0.548, Loss:  0.653
# Epoch   0 Batch  111/538 - Train Accuracy:  0.530, Validation Accuracy:  0.548, Loss:  0.621
# Epoch   0 Batch  112/538 - Train Accuracy:  0.490, Validation Accuracy:  0.528, Loss:  0.659
# Epoch   0 Batch  113/538 - Train Accuracy:  0.520, Validation Accuracy:  0.555, Loss:  0.658
# Epoch   0 Batch  114/538 - Train Accuracy:  0.590, Validation Accuracy:  0.568, Loss:  0.621
# Epoch   0 Batch  115/538 - Train Accuracy:  0.566, Validation Accuracy:  0.574, Loss:  0.650
# Epoch   0 Batch  116/538 - Train Accuracy:  0.545, Validation Accuracy:  0.568, Loss:  0.637
# Epoch   0 Batch  117/538 - Train Accuracy:  0.573, Validation Accuracy:  0.552, Loss:  0.609
# Epoch   0 Batch  118/538 - Train Accuracy:  0.576, Validation Accuracy:  0.557, Loss:  0.590
# Epoch   0 Batch  119/538 - Train Accuracy:  0.578, Validation Accuracy:  0.577, Loss:  0.594
# Epoch   0 Batch  120/538 - Train Accuracy:  0.574, Validation Accuracy:  0.579, Loss:  0.608
# Epoch   0 Batch  121/538 - Train Accuracy:  0.590, Validation Accuracy:  0.560, Loss:  0.594
# Epoch   0 Batch  122/538 - Train Accuracy:  0.519, Validation Accuracy:  0.517, Loss:  0.598
# Epoch   0 Batch  123/538 - Train Accuracy:  0.527, Validation Accuracy:  0.511, Loss:  0.581
# Epoch   0 Batch  124/538 - Train Accuracy:  0.518, Validation Accuracy:  0.519, Loss:  0.561
# Epoch   0 Batch  125/538 - Train Accuracy:  0.537, Validation Accuracy:  0.535, Loss:  0.597
# Epoch   0 Batch  126/538 - Train Accuracy:  0.585, Validation Accuracy:  0.553, Loss:  0.569
# Epoch   0 Batch  127/538 - Train Accuracy:  0.519, Validation Accuracy:  0.563, Loss:  0.638
# Epoch   0 Batch  128/538 - Train Accuracy:  0.553, Validation Accuracy:  0.556, Loss:  0.587
# Epoch   0 Batch  129/538 - Train Accuracy:  0.561, Validation Accuracy:  0.578, Loss:  0.577
# Epoch   0 Batch  130/538 - Train Accuracy:  0.567, Validation Accuracy:  0.586, Loss:  0.591
# Epoch   0 Batch  131/538 - Train Accuracy:  0.574, Validation Accuracy:  0.585, Loss:  0.596
# Epoch   0 Batch  132/538 - Train Accuracy:  0.555, Validation Accuracy:  0.582, Loss:  0.583
# Epoch   0 Batch  133/538 - Train Accuracy:  0.597, Validation Accuracy:  0.573, Loss:  0.557
# Epoch   0 Batch  134/538 - Train Accuracy:  0.570, Validation Accuracy:  0.568, Loss:  0.616
# Epoch   0 Batch  135/538 - Train Accuracy:  0.570, Validation Accuracy:  0.540, Loss:  0.596
# Epoch   0 Batch  136/538 - Train Accuracy:  0.562, Validation Accuracy:  0.570, Loss:  0.584
# Epoch   0 Batch  137/538 - Train Accuracy:  0.547, Validation Accuracy:  0.566, Loss:  0.587
# Epoch   0 Batch  138/538 - Train Accuracy:  0.571, Validation Accuracy:  0.556, Loss:  0.580
# Epoch   0 Batch  139/538 - Train Accuracy:  0.592, Validation Accuracy:  0.575, Loss:  0.613
# Epoch   0 Batch  140/538 - Train Accuracy:  0.532, Validation Accuracy:  0.586, Loss:  0.623
# Epoch   0 Batch  141/538 - Train Accuracy:  0.580, Validation Accuracy:  0.584, Loss:  0.602
# Epoch   0 Batch  142/538 - Train Accuracy:  0.605, Validation Accuracy:  0.591, Loss:  0.572
# Epoch   0 Batch  143/538 - Train Accuracy:  0.557, Validation Accuracy:  0.593, Loss:  0.608
# Epoch   0 Batch  144/538 - Train Accuracy:  0.591, Validation Accuracy:  0.617, Loss:  0.609
# Epoch   0 Batch  145/538 - Train Accuracy:  0.569, Validation Accuracy:  0.593, Loss:  0.583
# Epoch   0 Batch  146/538 - Train Accuracy:  0.538, Validation Accuracy:  0.556, Loss:  0.553
# Epoch   0 Batch  147/538 - Train Accuracy:  0.581, Validation Accuracy:  0.567, Loss:  0.549
# Epoch   0 Batch  148/538 - Train Accuracy:  0.546, Validation Accuracy:  0.577, Loss:  0.614
# Epoch   0 Batch  149/538 - Train Accuracy:  0.582, Validation Accuracy:  0.607, Loss:  0.574
# Epoch   0 Batch  150/538 - Train Accuracy:  0.603, Validation Accuracy:  0.607, Loss:  0.582
# Epoch   0 Batch  151/538 - Train Accuracy:  0.570, Validation Accuracy:  0.563, Loss:  0.552
# Epoch   0 Batch  152/538 - Train Accuracy:  0.596, Validation Accuracy:  0.585, Loss:  0.540
# Epoch   0 Batch  153/538 - Train Accuracy:  0.555, Validation Accuracy:  0.575, Loss:  0.578
# Epoch   0 Batch  154/538 - Train Accuracy:  0.594, Validation Accuracy:  0.595, Loss:  0.562
# Epoch   0 Batch  155/538 - Train Accuracy:  0.628, Validation Accuracy:  0.599, Loss:  0.561
# Epoch   0 Batch  156/538 - Train Accuracy:  0.590, Validation Accuracy:  0.602, Loss:  0.578
# Epoch   0 Batch  157/538 - Train Accuracy:  0.600, Validation Accuracy:  0.603, Loss:  0.537
# Epoch   0 Batch  158/538 - Train Accuracy:  0.555, Validation Accuracy:  0.574, Loss:  0.583
# Epoch   0 Batch  159/538 - Train Accuracy:  0.607, Validation Accuracy:  0.619, Loss:  0.572
# Epoch   0 Batch  160/538 - Train Accuracy:  0.590, Validation Accuracy:  0.604, Loss:  0.556
# Epoch   0 Batch  161/538 - Train Accuracy:  0.589, Validation Accuracy:  0.598, Loss:  0.582
# Epoch   0 Batch  162/538 - Train Accuracy:  0.592, Validation Accuracy:  0.590, Loss:  0.560
# Epoch   0 Batch  163/538 - Train Accuracy:  0.576, Validation Accuracy:  0.589, Loss:  0.557
# Epoch   0 Batch  164/538 - Train Accuracy:  0.573, Validation Accuracy:  0.604, Loss:  0.580
# Epoch   0 Batch  165/538 - Train Accuracy:  0.609, Validation Accuracy:  0.596, Loss:  0.527
# Epoch   0 Batch  166/538 - Train Accuracy:  0.602, Validation Accuracy:  0.570, Loss:  0.543
# Epoch   0 Batch  167/538 - Train Accuracy:  0.614, Validation Accuracy:  0.582, Loss:  0.547
# Epoch   0 Batch  168/538 - Train Accuracy:  0.575, Validation Accuracy:  0.599, Loss:  0.578
# Epoch   0 Batch  169/538 - Train Accuracy:  0.577, Validation Accuracy:  0.607, Loss:  0.546
# Epoch   0 Batch  170/538 - Train Accuracy:  0.614, Validation Accuracy:  0.606, Loss:  0.547
# Epoch   0 Batch  171/538 - Train Accuracy:  0.589, Validation Accuracy:  0.634, Loss:  0.569
# Epoch   0 Batch  172/538 - Train Accuracy:  0.615, Validation Accuracy:  0.616, Loss:  0.523
# Epoch   0 Batch  173/538 - Train Accuracy:  0.601, Validation Accuracy:  0.585, Loss:  0.519
# Epoch   0 Batch  174/538 - Train Accuracy:  0.577, Validation Accuracy:  0.588, Loss:  0.553
# Epoch   0 Batch  175/538 - Train Accuracy:  0.598, Validation Accuracy:  0.622, Loss:  0.546
# Epoch   0 Batch  176/538 - Train Accuracy:  0.614, Validation Accuracy:  0.613, Loss:  0.552
# Epoch   0 Batch  177/538 - Train Accuracy:  0.601, Validation Accuracy:  0.593, Loss:  0.517
# Epoch   0 Batch  178/538 - Train Accuracy:  0.618, Validation Accuracy:  0.595, Loss:  0.518
# Epoch   0 Batch  179/538 - Train Accuracy:  0.599, Validation Accuracy:  0.603, Loss:  0.536
# Epoch   0 Batch  180/538 - Train Accuracy:  0.609, Validation Accuracy:  0.592, Loss:  0.525
# Epoch   0 Batch  181/538 - Train Accuracy:  0.579, Validation Accuracy:  0.603, Loss:  0.545
# Epoch   0 Batch  182/538 - Train Accuracy:  0.575, Validation Accuracy:  0.640, Loss:  0.533
# Epoch   0 Batch  183/538 - Train Accuracy:  0.627, Validation Accuracy:  0.627, Loss:  0.499
# Epoch   0 Batch  184/538 - Train Accuracy:  0.623, Validation Accuracy:  0.641, Loss:  0.501
# Epoch   0 Batch  185/538 - Train Accuracy:  0.609, Validation Accuracy:  0.630, Loss:  0.518
# Epoch   0 Batch  186/538 - Train Accuracy:  0.597, Validation Accuracy:  0.628, Loss:  0.518
# Epoch   0 Batch  187/538 - Train Accuracy:  0.620, Validation Accuracy:  0.633, Loss:  0.485
# Epoch   0 Batch  188/538 - Train Accuracy:  0.587, Validation Accuracy:  0.624, Loss:  0.525
# Epoch   0 Batch  189/538 - Train Accuracy:  0.616, Validation Accuracy:  0.628, Loss:  0.523
# Epoch   0 Batch  190/538 - Train Accuracy:  0.621, Validation Accuracy:  0.620, Loss:  0.517
# Epoch   0 Batch  191/538 - Train Accuracy:  0.659, Validation Accuracy:  0.626, Loss:  0.491
# Epoch   0 Batch  192/538 - Train Accuracy:  0.603, Validation Accuracy:  0.627, Loss:  0.491
# Epoch   0 Batch  193/538 - Train Accuracy:  0.628, Validation Accuracy:  0.630, Loss:  0.493
# Epoch   0 Batch  194/538 - Train Accuracy:  0.603, Validation Accuracy:  0.639, Loss:  0.538
# Epoch   0 Batch  195/538 - Train Accuracy:  0.621, Validation Accuracy:  0.636, Loss:  0.488
# Epoch   0 Batch  196/538 - Train Accuracy:  0.623, Validation Accuracy:  0.634, Loss:  0.490
# Epoch   0 Batch  197/538 - Train Accuracy:  0.622, Validation Accuracy:  0.638, Loss:  0.493
# Epoch   0 Batch  198/538 - Train Accuracy:  0.647, Validation Accuracy:  0.617, Loss:  0.487
# Epoch   0 Batch  199/538 - Train Accuracy:  0.581, Validation Accuracy:  0.604, Loss:  0.506
# Epoch   0 Batch  200/538 - Train Accuracy:  0.607, Validation Accuracy:  0.604, Loss:  0.505
# Epoch   0 Batch  201/538 - Train Accuracy:  0.595, Validation Accuracy:  0.608, Loss:  0.509
# Epoch   0 Batch  202/538 - Train Accuracy:  0.614, Validation Accuracy:  0.642, Loss:  0.537
# Epoch   0 Batch  203/538 - Train Accuracy:  0.612, Validation Accuracy:  0.642, Loss:  0.530
# Epoch   0 Batch  204/538 - Train Accuracy:  0.590, Validation Accuracy:  0.635, Loss:  0.519
# Epoch   0 Batch  205/538 - Train Accuracy:  0.623, Validation Accuracy:  0.625, Loss:  0.485
# Epoch   0 Batch  206/538 - Train Accuracy:  0.584, Validation Accuracy:  0.622, Loss:  0.511
# Epoch   0 Batch  207/538 - Train Accuracy:  0.613, Validation Accuracy:  0.630, Loss:  0.478
# Epoch   0 Batch  208/538 - Train Accuracy:  0.607, Validation Accuracy:  0.637, Loss:  0.503
# Epoch   0 Batch  209/538 - Train Accuracy:  0.608, Validation Accuracy:  0.647, Loss:  0.499
# Epoch   0 Batch  210/538 - Train Accuracy:  0.624, Validation Accuracy:  0.654, Loss:  0.489
# Epoch   0 Batch  211/538 - Train Accuracy:  0.607, Validation Accuracy:  0.639, Loss:  0.511
# Epoch   0 Batch  212/538 - Train Accuracy:  0.620, Validation Accuracy:  0.628, Loss:  0.479
# Epoch   0 Batch  213/538 - Train Accuracy:  0.616, Validation Accuracy:  0.629, Loss:  0.476
# Epoch   0 Batch  214/538 - Train Accuracy:  0.597, Validation Accuracy:  0.624, Loss:  0.488
# Epoch   0 Batch  215/538 - Train Accuracy:  0.624, Validation Accuracy:  0.647, Loss:  0.495
# Epoch   0 Batch  216/538 - Train Accuracy:  0.596, Validation Accuracy:  0.648, Loss:  0.508
# Epoch   0 Batch  217/538 - Train Accuracy:  0.655, Validation Accuracy:  0.642, Loss:  0.470
# Epoch   0 Batch  218/538 - Train Accuracy:  0.594, Validation Accuracy:  0.653, Loss:  0.504
# Epoch   0 Batch  219/538 - Train Accuracy:  0.610, Validation Accuracy:  0.641, Loss:  0.510
# Epoch   0 Batch  220/538 - Train Accuracy:  0.602, Validation Accuracy:  0.632, Loss:  0.459
# Epoch   0 Batch  221/538 - Train Accuracy:  0.635, Validation Accuracy:  0.620, Loss:  0.460
# Epoch   0 Batch  222/538 - Train Accuracy:  0.644, Validation Accuracy:  0.633, Loss:  0.450
# Epoch   0 Batch  223/538 - Train Accuracy:  0.613, Validation Accuracy:  0.636, Loss:  0.487
# Epoch   0 Batch  224/538 - Train Accuracy:  0.622, Validation Accuracy:  0.645, Loss:  0.486
# Epoch   0 Batch  225/538 - Train Accuracy:  0.641, Validation Accuracy:  0.640, Loss:  0.453
# Epoch   0 Batch  226/538 - Train Accuracy:  0.647, Validation Accuracy:  0.666, Loss:  0.462
# Epoch   0 Batch  227/538 - Train Accuracy:  0.664, Validation Accuracy:  0.653, Loss:  0.446
# Epoch   0 Batch  228/538 - Train Accuracy:  0.624, Validation Accuracy:  0.659, Loss:  0.460
# Epoch   0 Batch  229/538 - Train Accuracy:  0.624, Validation Accuracy:  0.664, Loss:  0.462
# Epoch   0 Batch  230/538 - Train Accuracy:  0.626, Validation Accuracy:  0.648, Loss:  0.469
# Epoch   0 Batch  231/538 - Train Accuracy:  0.632, Validation Accuracy:  0.638, Loss:  0.477
# Epoch   0 Batch  232/538 - Train Accuracy:  0.619, Validation Accuracy:  0.651, Loss:  0.484
# Epoch   0 Batch  233/538 - Train Accuracy:  0.669, Validation Accuracy:  0.664, Loss:  0.448
# Epoch   0 Batch  234/538 - Train Accuracy:  0.612, Validation Accuracy:  0.656, Loss:  0.474
# Epoch   0 Batch  235/538 - Train Accuracy:  0.648, Validation Accuracy:  0.650, Loss:  0.448
# Epoch   0 Batch  236/538 - Train Accuracy:  0.631, Validation Accuracy:  0.635, Loss:  0.478
# Epoch   0 Batch  237/538 - Train Accuracy:  0.652, Validation Accuracy:  0.653, Loss:  0.448
# Epoch   0 Batch  238/538 - Train Accuracy:  0.684, Validation Accuracy:  0.665, Loss:  0.441
# Epoch   0 Batch  239/538 - Train Accuracy:  0.659, Validation Accuracy:  0.657, Loss:  0.462
# Epoch   0 Batch  240/538 - Train Accuracy:  0.631, Validation Accuracy:  0.653, Loss:  0.447
# Epoch   0 Batch  241/538 - Train Accuracy:  0.614, Validation Accuracy:  0.632, Loss:  0.466
# Epoch   0 Batch  242/538 - Train Accuracy:  0.659, Validation Accuracy:  0.654, Loss:  0.452
# Epoch   0 Batch  243/538 - Train Accuracy:  0.614, Validation Accuracy:  0.652, Loss:  0.484
# Epoch   0 Batch  244/538 - Train Accuracy:  0.661, Validation Accuracy:  0.656, Loss:  0.458
# Epoch   0 Batch  245/538 - Train Accuracy:  0.633, Validation Accuracy:  0.645, Loss:  0.476
# Epoch   0 Batch  246/538 - Train Accuracy:  0.666, Validation Accuracy:  0.648, Loss:  0.421
# Epoch   0 Batch  247/538 - Train Accuracy:  0.627, Validation Accuracy:  0.649, Loss:  0.467
# Epoch   0 Batch  248/538 - Train Accuracy:  0.654, Validation Accuracy:  0.663, Loss:  0.465
# Epoch   0 Batch  249/538 - Train Accuracy:  0.639, Validation Accuracy:  0.658, Loss:  0.454
# Epoch   0 Batch  250/538 - Train Accuracy:  0.647, Validation Accuracy:  0.652, Loss:  0.470
# Epoch   0 Batch  251/538 - Train Accuracy:  0.627, Validation Accuracy:  0.657, Loss:  0.460
# Epoch   0 Batch  252/538 - Train Accuracy:  0.652, Validation Accuracy:  0.657, Loss:  0.445
# Epoch   0 Batch  253/538 - Train Accuracy:  0.642, Validation Accuracy:  0.655, Loss:  0.439
# Epoch   0 Batch  254/538 - Train Accuracy:  0.653, Validation Accuracy:  0.652, Loss:  0.450
# Epoch   0 Batch  255/538 - Train Accuracy:  0.636, Validation Accuracy:  0.639, Loss:  0.442
# Epoch   0 Batch  256/538 - Train Accuracy:  0.652, Validation Accuracy:  0.663, Loss:  0.458
# Epoch   0 Batch  257/538 - Train Accuracy:  0.675, Validation Accuracy:  0.677, Loss:  0.430
# Epoch   0 Batch  258/538 - Train Accuracy:  0.681, Validation Accuracy:  0.663, Loss:  0.439
# Epoch   0 Batch  259/538 - Train Accuracy:  0.689, Validation Accuracy:  0.671, Loss:  0.414
# Epoch   0 Batch  260/538 - Train Accuracy:  0.648, Validation Accuracy:  0.673, Loss:  0.428
# Epoch   0 Batch  261/538 - Train Accuracy:  0.653, Validation Accuracy:  0.640, Loss:  0.446
# Epoch   0 Batch  262/538 - Train Accuracy:  0.635, Validation Accuracy:  0.632, Loss:  0.441
# Epoch   0 Batch  263/538 - Train Accuracy:  0.638, Validation Accuracy:  0.633, Loss:  0.429
# Epoch   0 Batch  264/538 - Train Accuracy:  0.621, Validation Accuracy:  0.645, Loss:  0.459
# Epoch   0 Batch  265/538 - Train Accuracy:  0.590, Validation Accuracy:  0.637, Loss:  0.465
# Epoch   0 Batch  266/538 - Train Accuracy:  0.667, Validation Accuracy:  0.659, Loss:  0.436
# Epoch   0 Batch  267/538 - Train Accuracy:  0.651, Validation Accuracy:  0.651, Loss:  0.430
# Epoch   0 Batch  268/538 - Train Accuracy:  0.671, Validation Accuracy:  0.665, Loss:  0.422
# Epoch   0 Batch  269/538 - Train Accuracy:  0.660, Validation Accuracy:  0.665, Loss:  0.432
# Epoch   0 Batch  270/538 - Train Accuracy:  0.659, Validation Accuracy:  0.673, Loss:  0.440
# Epoch   0 Batch  271/538 - Train Accuracy:  0.661, Validation Accuracy:  0.670, Loss:  0.432
# Epoch   0 Batch  272/538 - Train Accuracy:  0.628, Validation Accuracy:  0.669, Loss:  0.452
# Epoch   0 Batch  273/538 - Train Accuracy:  0.665, Validation Accuracy:  0.671, Loss:  0.420
# Epoch   0 Batch  274/538 - Train Accuracy:  0.628, Validation Accuracy:  0.666, Loss:  0.454
# Epoch   0 Batch  275/538 - Train Accuracy:  0.640, Validation Accuracy:  0.646, Loss:  0.447
# Epoch   0 Batch  276/538 - Train Accuracy:  0.653, Validation Accuracy:  0.651, Loss:  0.431
# Epoch   0 Batch  277/538 - Train Accuracy:  0.669, Validation Accuracy:  0.669, Loss:  0.424
# Epoch   0 Batch  278/538 - Train Accuracy:  0.666, Validation Accuracy:  0.678, Loss:  0.427
# Epoch   0 Batch  279/538 - Train Accuracy:  0.673, Validation Accuracy:  0.681, Loss:  0.425
# Epoch   0 Batch  280/538 - Train Accuracy:  0.705, Validation Accuracy:  0.672, Loss:  0.394
# Epoch   0 Batch  281/538 - Train Accuracy:  0.658, Validation Accuracy:  0.656, Loss:  0.429
# Epoch   0 Batch  282/538 - Train Accuracy:  0.652, Validation Accuracy:  0.645, Loss:  0.422
# Epoch   0 Batch  283/538 - Train Accuracy:  0.664, Validation Accuracy:  0.667, Loss:  0.420
# Epoch   0 Batch  284/538 - Train Accuracy:  0.687, Validation Accuracy:  0.670, Loss:  0.418
# Epoch   0 Batch  285/538 - Train Accuracy:  0.666, Validation Accuracy:  0.675, Loss:  0.399
# Epoch   0 Batch  286/538 - Train Accuracy:  0.673, Validation Accuracy:  0.677, Loss:  0.414
# Epoch   0 Batch  287/538 - Train Accuracy:  0.686, Validation Accuracy:  0.671, Loss:  0.401
# Epoch   0 Batch  288/538 - Train Accuracy:  0.662, Validation Accuracy:  0.668, Loss:  0.416
# Epoch   0 Batch  289/538 - Train Accuracy:  0.691, Validation Accuracy:  0.681, Loss:  0.384
# Epoch   0 Batch  290/538 - Train Accuracy:  0.662, Validation Accuracy:  0.654, Loss:  0.402
# Epoch   0 Batch  291/538 - Train Accuracy:  0.674, Validation Accuracy:  0.646, Loss:  0.403
# Epoch   0 Batch  292/538 - Train Accuracy:  0.694, Validation Accuracy:  0.673, Loss:  0.381
# Epoch   0 Batch  293/538 - Train Accuracy:  0.699, Validation Accuracy:  0.666, Loss:  0.378
# Epoch   0 Batch  294/538 - Train Accuracy:  0.655, Validation Accuracy:  0.682, Loss:  0.416
# Epoch   0 Batch  295/538 - Train Accuracy:  0.683, Validation Accuracy:  0.682, Loss:  0.382
# Epoch   0 Batch  296/538 - Train Accuracy:  0.678, Validation Accuracy:  0.681, Loss:  0.407
# Epoch   0 Batch  297/538 - Train Accuracy:  0.680, Validation Accuracy:  0.699, Loss:  0.408
# Epoch   0 Batch  298/538 - Train Accuracy:  0.677, Validation Accuracy:  0.695, Loss:  0.378
# Epoch   0 Batch  299/538 - Train Accuracy:  0.670, Validation Accuracy:  0.701, Loss:  0.391
# Epoch   0 Batch  300/538 - Train Accuracy:  0.657, Validation Accuracy:  0.696, Loss:  0.390
# Epoch   0 Batch  301/538 - Train Accuracy:  0.671, Validation Accuracy:  0.689, Loss:  0.395
# Epoch   0 Batch  302/538 - Train Accuracy:  0.695, Validation Accuracy:  0.688, Loss:  0.365
# Epoch   0 Batch  303/538 - Train Accuracy:  0.711, Validation Accuracy:  0.687, Loss:  0.361
# Epoch   0 Batch  304/538 - Train Accuracy:  0.657, Validation Accuracy:  0.688, Loss:  0.379
# Epoch   0 Batch  305/538 - Train Accuracy:  0.687, Validation Accuracy:  0.691, Loss:  0.378
# Epoch   0 Batch  306/538 - Train Accuracy:  0.686, Validation Accuracy:  0.684, Loss:  0.366
# Epoch   0 Batch  307/538 - Train Accuracy:  0.680, Validation Accuracy:  0.693, Loss:  0.376
# Epoch   0 Batch  308/538 - Train Accuracy:  0.681, Validation Accuracy:  0.688, Loss:  0.371
# Epoch   0 Batch  309/538 - Train Accuracy:  0.673, Validation Accuracy:  0.682, Loss:  0.378
# Epoch   0 Batch  310/538 - Train Accuracy:  0.703, Validation Accuracy:  0.690, Loss:  0.390
# Epoch   0 Batch  311/538 - Train Accuracy:  0.703, Validation Accuracy:  0.690, Loss:  0.368
# Epoch   0 Batch  312/538 - Train Accuracy:  0.720, Validation Accuracy:  0.697, Loss:  0.347
# Epoch   0 Batch  313/538 - Train Accuracy:  0.670, Validation Accuracy:  0.700, Loss:  0.391
# Epoch   0 Batch  314/538 - Train Accuracy:  0.689, Validation Accuracy:  0.696, Loss:  0.370
# Epoch   0 Batch  315/538 - Train Accuracy:  0.677, Validation Accuracy:  0.707, Loss:  0.368
# Epoch   0 Batch  316/538 - Train Accuracy:  0.679, Validation Accuracy:  0.703, Loss:  0.358
# Epoch   0 Batch  317/538 - Train Accuracy:  0.684, Validation Accuracy:  0.709, Loss:  0.375
# Epoch   0 Batch  318/538 - Train Accuracy:  0.671, Validation Accuracy:  0.711, Loss:  0.362
# Epoch   0 Batch  319/538 - Train Accuracy:  0.696, Validation Accuracy:  0.693, Loss:  0.358
# Epoch   0 Batch  320/538 - Train Accuracy:  0.685, Validation Accuracy:  0.711, Loss:  0.360
# Epoch   0 Batch  321/538 - Train Accuracy:  0.693, Validation Accuracy:  0.693, Loss:  0.341
# Epoch   0 Batch  322/538 - Train Accuracy:  0.720, Validation Accuracy:  0.699, Loss:  0.336
# Epoch   0 Batch  323/538 - Train Accuracy:  0.717, Validation Accuracy:  0.700, Loss:  0.353
# Epoch   0 Batch  324/538 - Train Accuracy:  0.679, Validation Accuracy:  0.693, Loss:  0.366
# Epoch   0 Batch  325/538 - Train Accuracy:  0.690, Validation Accuracy:  0.687, Loss:  0.353
# Epoch   0 Batch  326/538 - Train Accuracy:  0.696, Validation Accuracy:  0.686, Loss:  0.369
# Epoch   0 Batch  327/538 - Train Accuracy:  0.682, Validation Accuracy:  0.685, Loss:  0.372
# Epoch   0 Batch  328/538 - Train Accuracy:  0.701, Validation Accuracy:  0.687, Loss:  0.350
# Epoch   0 Batch  329/538 - Train Accuracy:  0.712, Validation Accuracy:  0.678, Loss:  0.340
# Epoch   0 Batch  330/538 - Train Accuracy:  0.694, Validation Accuracy:  0.678, Loss:  0.338
# Epoch   0 Batch  331/538 - Train Accuracy:  0.713, Validation Accuracy:  0.682, Loss:  0.346
# Epoch   0 Batch  332/538 - Train Accuracy:  0.708, Validation Accuracy:  0.698, Loss:  0.376
# Epoch   0 Batch  333/538 - Train Accuracy:  0.706, Validation Accuracy:  0.685, Loss:  0.346
# Epoch   0 Batch  334/538 - Train Accuracy:  0.709, Validation Accuracy:  0.688, Loss:  0.345
# Epoch   0 Batch  335/538 - Train Accuracy:  0.700, Validation Accuracy:  0.700, Loss:  0.344
# Epoch   0 Batch  336/538 - Train Accuracy:  0.711, Validation Accuracy:  0.692, Loss:  0.336
# Epoch   0 Batch  337/538 - Train Accuracy:  0.730, Validation Accuracy:  0.691, Loss:  0.338
# Epoch   0 Batch  338/538 - Train Accuracy:  0.699, Validation Accuracy:  0.712, Loss:  0.359
# Epoch   0 Batch  339/538 - Train Accuracy:  0.718, Validation Accuracy:  0.704, Loss:  0.330
# Epoch   0 Batch  340/538 - Train Accuracy:  0.667, Validation Accuracy:  0.708, Loss:  0.357
# Epoch   0 Batch  341/538 - Train Accuracy:  0.715, Validation Accuracy:  0.707, Loss:  0.343
# Epoch   0 Batch  342/538 - Train Accuracy:  0.717, Validation Accuracy:  0.701, Loss:  0.332
# Epoch   0 Batch  343/538 - Train Accuracy:  0.717, Validation Accuracy:  0.693, Loss:  0.356
# Epoch   0 Batch  344/538 - Train Accuracy:  0.712, Validation Accuracy:  0.708, Loss:  0.352
# Epoch   0 Batch  345/538 - Train Accuracy:  0.708, Validation Accuracy:  0.706, Loss:  0.337
# Epoch   0 Batch  346/538 - Train Accuracy:  0.700, Validation Accuracy:  0.714, Loss:  0.331
# Epoch   0 Batch  347/538 - Train Accuracy:  0.722, Validation Accuracy:  0.722, Loss:  0.339
# Epoch   0 Batch  348/538 - Train Accuracy:  0.705, Validation Accuracy:  0.713, Loss:  0.322
# Epoch   0 Batch  349/538 - Train Accuracy:  0.682, Validation Accuracy:  0.721, Loss:  0.333
# Epoch   0 Batch  350/538 - Train Accuracy:  0.727, Validation Accuracy:  0.727, Loss:  0.339
# Epoch   0 Batch  351/538 - Train Accuracy:  0.688, Validation Accuracy:  0.716, Loss:  0.350
# Epoch   0 Batch  352/538 - Train Accuracy:  0.720, Validation Accuracy:  0.702, Loss:  0.341
# Epoch   0 Batch  353/538 - Train Accuracy:  0.715, Validation Accuracy:  0.724, Loss:  0.333
# Epoch   0 Batch  354/538 - Train Accuracy:  0.684, Validation Accuracy:  0.708, Loss:  0.341
# Epoch   0 Batch  355/538 - Train Accuracy:  0.700, Validation Accuracy:  0.709, Loss:  0.335
# Epoch   0 Batch  356/538 - Train Accuracy:  0.713, Validation Accuracy:  0.718, Loss:  0.313
# Epoch   0 Batch  357/538 - Train Accuracy:  0.732, Validation Accuracy:  0.713, Loss:  0.307
# Epoch   0 Batch  358/538 - Train Accuracy:  0.739, Validation Accuracy:  0.714, Loss:  0.333
# Epoch   0 Batch  359/538 - Train Accuracy:  0.716, Validation Accuracy:  0.714, Loss:  0.333
# Epoch   0 Batch  360/538 - Train Accuracy:  0.688, Validation Accuracy:  0.717, Loss:  0.333
# Epoch   0 Batch  361/538 - Train Accuracy:  0.733, Validation Accuracy:  0.719, Loss:  0.329
# Epoch   0 Batch  362/538 - Train Accuracy:  0.736, Validation Accuracy:  0.723, Loss:  0.311
# Epoch   0 Batch  363/538 - Train Accuracy:  0.718, Validation Accuracy:  0.695, Loss:  0.302
# Epoch   0 Batch  364/538 - Train Accuracy:  0.714, Validation Accuracy:  0.694, Loss:  0.336
# Epoch   0 Batch  365/538 - Train Accuracy:  0.730, Validation Accuracy:  0.697, Loss:  0.315
# Epoch   0 Batch  366/538 - Train Accuracy:  0.725, Validation Accuracy:  0.708, Loss:  0.347
# Epoch   0 Batch  367/538 - Train Accuracy:  0.739, Validation Accuracy:  0.714, Loss:  0.311
# Epoch   0 Batch  368/538 - Train Accuracy:  0.756, Validation Accuracy:  0.723, Loss:  0.288
# Epoch   0 Batch  369/538 - Train Accuracy:  0.731, Validation Accuracy:  0.732, Loss:  0.307
# Epoch   0 Batch  370/538 - Train Accuracy:  0.727, Validation Accuracy:  0.719, Loss:  0.329
# Epoch   0 Batch  371/538 - Train Accuracy:  0.739, Validation Accuracy:  0.724, Loss:  0.299
# Epoch   0 Batch  372/538 - Train Accuracy:  0.725, Validation Accuracy:  0.732, Loss:  0.309
# Epoch   0 Batch  373/538 - Train Accuracy:  0.739, Validation Accuracy:  0.751, Loss:  0.298
# Epoch   0 Batch  374/538 - Train Accuracy:  0.707, Validation Accuracy:  0.751, Loss:  0.318
# Epoch   0 Batch  375/538 - Train Accuracy:  0.764, Validation Accuracy:  0.735, Loss:  0.288
# Epoch   0 Batch  376/538 - Train Accuracy:  0.742, Validation Accuracy:  0.736, Loss:  0.305
# Epoch   0 Batch  377/538 - Train Accuracy:  0.734, Validation Accuracy:  0.745, Loss:  0.298
# Epoch   0 Batch  378/538 - Train Accuracy:  0.782, Validation Accuracy:  0.744, Loss:  0.271
# Epoch   0 Batch  379/538 - Train Accuracy:  0.755, Validation Accuracy:  0.737, Loss:  0.277
# Epoch   0 Batch  380/538 - Train Accuracy:  0.742, Validation Accuracy:  0.720, Loss:  0.287
# Epoch   0 Batch  381/538 - Train Accuracy:  0.743, Validation Accuracy:  0.710, Loss:  0.282
# Epoch   0 Batch  382/538 - Train Accuracy:  0.717, Validation Accuracy:  0.727, Loss:  0.304
# Epoch   0 Batch  383/538 - Train Accuracy:  0.732, Validation Accuracy:  0.732, Loss:  0.304
# Epoch   0 Batch  384/538 - Train Accuracy:  0.747, Validation Accuracy:  0.717, Loss:  0.277
# Epoch   0 Batch  385/538 - Train Accuracy:  0.759, Validation Accuracy:  0.726, Loss:  0.281
# Epoch   0 Batch  386/538 - Train Accuracy:  0.741, Validation Accuracy:  0.723, Loss:  0.299
# Epoch   0 Batch  387/538 - Train Accuracy:  0.748, Validation Accuracy:  0.719, Loss:  0.298
# Epoch   0 Batch  388/538 - Train Accuracy:  0.744, Validation Accuracy:  0.734, Loss:  0.303
# Epoch   0 Batch  389/538 - Train Accuracy:  0.730, Validation Accuracy:  0.731, Loss:  0.301
# Epoch   0 Batch  390/538 - Train Accuracy:  0.767, Validation Accuracy:  0.733, Loss:  0.297
# Epoch   0 Batch  391/538 - Train Accuracy:  0.746, Validation Accuracy:  0.740, Loss:  0.286
# Epoch   0 Batch  392/538 - Train Accuracy:  0.755, Validation Accuracy:  0.748, Loss:  0.295
# Epoch   0 Batch  393/538 - Train Accuracy:  0.762, Validation Accuracy:  0.716, Loss:  0.272
# Epoch   0 Batch  394/538 - Train Accuracy:  0.706, Validation Accuracy:  0.722, Loss:  0.323
# Epoch   0 Batch  395/538 - Train Accuracy:  0.743, Validation Accuracy:  0.739, Loss:  0.308
# Epoch   0 Batch  396/538 - Train Accuracy:  0.722, Validation Accuracy:  0.754, Loss:  0.284
# Epoch   0 Batch  397/538 - Train Accuracy:  0.736, Validation Accuracy:  0.746, Loss:  0.283
# Epoch   0 Batch  398/538 - Train Accuracy:  0.728, Validation Accuracy:  0.738, Loss:  0.300
# Epoch   0 Batch  399/538 - Train Accuracy:  0.721, Validation Accuracy:  0.737, Loss:  0.303
# Epoch   0 Batch  400/538 - Train Accuracy:  0.738, Validation Accuracy:  0.734, Loss:  0.285
# Epoch   0 Batch  401/538 - Train Accuracy:  0.770, Validation Accuracy:  0.734, Loss:  0.301
# Epoch   0 Batch  402/538 - Train Accuracy:  0.750, Validation Accuracy:  0.729, Loss:  0.278
# Epoch   0 Batch  403/538 - Train Accuracy:  0.718, Validation Accuracy:  0.731, Loss:  0.292
# Epoch   0 Batch  404/538 - Train Accuracy:  0.749, Validation Accuracy:  0.743, Loss:  0.272
# Epoch   0 Batch  405/538 - Train Accuracy:  0.747, Validation Accuracy:  0.751, Loss:  0.277
# Epoch   0 Batch  406/538 - Train Accuracy:  0.756, Validation Accuracy:  0.763, Loss:  0.277
# Epoch   0 Batch  407/538 - Train Accuracy:  0.779, Validation Accuracy:  0.753, Loss:  0.283
# Epoch   0 Batch  408/538 - Train Accuracy:  0.767, Validation Accuracy:  0.751, Loss:  0.279
# Epoch   0 Batch  409/538 - Train Accuracy:  0.752, Validation Accuracy:  0.747, Loss:  0.297
# Epoch   0 Batch  410/538 - Train Accuracy:  0.749, Validation Accuracy:  0.752, Loss:  0.279
# Epoch   0 Batch  411/538 - Train Accuracy:  0.771, Validation Accuracy:  0.771, Loss:  0.270
# Epoch   0 Batch  412/538 - Train Accuracy:  0.755, Validation Accuracy:  0.747, Loss:  0.271
# Epoch   0 Batch  413/538 - Train Accuracy:  0.773, Validation Accuracy:  0.744, Loss:  0.282
# Epoch   0 Batch  414/538 - Train Accuracy:  0.756, Validation Accuracy:  0.766, Loss:  0.283
# Epoch   0 Batch  415/538 - Train Accuracy:  0.735, Validation Accuracy:  0.755, Loss:  0.291
# Epoch   0 Batch  416/538 - Train Accuracy:  0.771, Validation Accuracy:  0.749, Loss:  0.264
# Epoch   0 Batch  417/538 - Train Accuracy:  0.773, Validation Accuracy:  0.757, Loss:  0.259
# Epoch   0 Batch  418/538 - Train Accuracy:  0.755, Validation Accuracy:  0.754, Loss:  0.287
# Epoch   0 Batch  419/538 - Train Accuracy:  0.775, Validation Accuracy:  0.750, Loss:  0.254
# Epoch   0 Batch  420/538 - Train Accuracy:  0.773, Validation Accuracy:  0.753, Loss:  0.264
# Epoch   0 Batch  421/538 - Train Accuracy:  0.777, Validation Accuracy:  0.762, Loss:  0.251
# Epoch   0 Batch  422/538 - Train Accuracy:  0.767, Validation Accuracy:  0.756, Loss:  0.266
# Epoch   0 Batch  423/538 - Train Accuracy:  0.785, Validation Accuracy:  0.763, Loss:  0.275
# Epoch   0 Batch  424/538 - Train Accuracy:  0.741, Validation Accuracy:  0.753, Loss:  0.276
# Epoch   0 Batch  425/538 - Train Accuracy:  0.764, Validation Accuracy:  0.763, Loss:  0.266
# Epoch   0 Batch  426/538 - Train Accuracy:  0.766, Validation Accuracy:  0.747, Loss:  0.257
# Epoch   0 Batch  427/538 - Train Accuracy:  0.763, Validation Accuracy:  0.751, Loss:  0.277
# Epoch   0 Batch  428/538 - Train Accuracy:  0.779, Validation Accuracy:  0.748, Loss:  0.241
# Epoch   0 Batch  429/538 - Train Accuracy:  0.787, Validation Accuracy:  0.762, Loss:  0.259
# Epoch   0 Batch  430/538 - Train Accuracy:  0.757, Validation Accuracy:  0.763, Loss:  0.262
# Epoch   0 Batch  431/538 - Train Accuracy:  0.758, Validation Accuracy:  0.760, Loss:  0.252
# Epoch   0 Batch  432/538 - Train Accuracy:  0.797, Validation Accuracy:  0.762, Loss:  0.247
# Epoch   0 Batch  433/538 - Train Accuracy:  0.749, Validation Accuracy:  0.768, Loss:  0.282
# Epoch   0 Batch  434/538 - Train Accuracy:  0.758, Validation Accuracy:  0.764, Loss:  0.253
# Epoch   0 Batch  435/538 - Train Accuracy:  0.763, Validation Accuracy:  0.762, Loss:  0.255
# Epoch   0 Batch  436/538 - Train Accuracy:  0.758, Validation Accuracy:  0.749, Loss:  0.247
# Epoch   0 Batch  437/538 - Train Accuracy:  0.783, Validation Accuracy:  0.771, Loss:  0.258
# Epoch   0 Batch  438/538 - Train Accuracy:  0.788, Validation Accuracy:  0.771, Loss:  0.252
# Epoch   0 Batch  439/538 - Train Accuracy:  0.789, Validation Accuracy:  0.771, Loss:  0.250
# Epoch   0 Batch  440/538 - Train Accuracy:  0.779, Validation Accuracy:  0.773, Loss:  0.256
# Epoch   0 Batch  441/538 - Train Accuracy:  0.740, Validation Accuracy:  0.766, Loss:  0.245
# Epoch   0 Batch  442/538 - Train Accuracy:  0.801, Validation Accuracy:  0.769, Loss:  0.222
# Epoch   0 Batch  443/538 - Train Accuracy:  0.787, Validation Accuracy:  0.770, Loss:  0.240
# Epoch   0 Batch  444/538 - Train Accuracy:  0.792, Validation Accuracy:  0.779, Loss:  0.233
# Epoch   0 Batch  445/538 - Train Accuracy:  0.774, Validation Accuracy:  0.778, Loss:  0.240
# Epoch   0 Batch  446/538 - Train Accuracy:  0.790, Validation Accuracy:  0.775, Loss:  0.226
# Epoch   0 Batch  447/538 - Train Accuracy:  0.773, Validation Accuracy:  0.775, Loss:  0.245
# Epoch   0 Batch  448/538 - Train Accuracy:  0.807, Validation Accuracy:  0.776, Loss:  0.215
# Epoch   0 Batch  449/538 - Train Accuracy:  0.790, Validation Accuracy:  0.777, Loss:  0.241
# Epoch   0 Batch  450/538 - Train Accuracy:  0.773, Validation Accuracy:  0.758, Loss:  0.245
# Epoch   0 Batch  451/538 - Train Accuracy:  0.766, Validation Accuracy:  0.752, Loss:  0.238
# Epoch   0 Batch  452/538 - Train Accuracy:  0.777, Validation Accuracy:  0.766, Loss:  0.227
# Epoch   0 Batch  453/538 - Train Accuracy:  0.806, Validation Accuracy:  0.764, Loss:  0.231
# Epoch   0 Batch  454/538 - Train Accuracy:  0.780, Validation Accuracy:  0.777, Loss:  0.237
# Epoch   0 Batch  455/538 - Train Accuracy:  0.817, Validation Accuracy:  0.785, Loss:  0.204
# Epoch   0 Batch  456/538 - Train Accuracy:  0.801, Validation Accuracy:  0.777, Loss:  0.214
# Epoch   0 Batch  457/538 - Train Accuracy:  0.793, Validation Accuracy:  0.772, Loss:  0.224
# Epoch   0 Batch  458/538 - Train Accuracy:  0.794, Validation Accuracy:  0.770, Loss:  0.219
# Epoch   0 Batch  459/538 - Train Accuracy:  0.805, Validation Accuracy:  0.777, Loss:  0.224
# Epoch   0 Batch  460/538 - Train Accuracy:  0.757, Validation Accuracy:  0.768, Loss:  0.218
# Epoch   0 Batch  461/538 - Train Accuracy:  0.745, Validation Accuracy:  0.769, Loss:  0.240
# Epoch   0 Batch  462/538 - Train Accuracy:  0.791, Validation Accuracy:  0.775, Loss:  0.228
# Epoch   0 Batch  463/538 - Train Accuracy:  0.781, Validation Accuracy:  0.776, Loss:  0.227
# Epoch   0 Batch  464/538 - Train Accuracy:  0.764, Validation Accuracy:  0.772, Loss:  0.227
# Epoch   0 Batch  465/538 - Train Accuracy:  0.760, Validation Accuracy:  0.767, Loss:  0.230
# Epoch   0 Batch  466/538 - Train Accuracy:  0.787, Validation Accuracy:  0.777, Loss:  0.230
# Epoch   0 Batch  467/538 - Train Accuracy:  0.775, Validation Accuracy:  0.758, Loss:  0.216
# Epoch   0 Batch  468/538 - Train Accuracy:  0.817, Validation Accuracy:  0.764, Loss:  0.226
# Epoch   0 Batch  469/538 - Train Accuracy:  0.789, Validation Accuracy:  0.766, Loss:  0.219
# Epoch   0 Batch  470/538 - Train Accuracy:  0.778, Validation Accuracy:  0.770, Loss:  0.218
# Epoch   0 Batch  471/538 - Train Accuracy:  0.779, Validation Accuracy:  0.773, Loss:  0.212
# Epoch   0 Batch  472/538 - Train Accuracy:  0.819, Validation Accuracy:  0.775, Loss:  0.204
# Epoch   0 Batch  473/538 - Train Accuracy:  0.765, Validation Accuracy:  0.767, Loss:  0.234
# Epoch   0 Batch  474/538 - Train Accuracy:  0.794, Validation Accuracy:  0.779, Loss:  0.211
# Epoch   0 Batch  475/538 - Train Accuracy:  0.798, Validation Accuracy:  0.794, Loss:  0.211
# Epoch   0 Batch  476/538 - Train Accuracy:  0.776, Validation Accuracy:  0.784, Loss:  0.215
# Epoch   0 Batch  477/538 - Train Accuracy:  0.770, Validation Accuracy:  0.771, Loss:  0.228
# Epoch   0 Batch  478/538 - Train Accuracy:  0.818, Validation Accuracy:  0.776, Loss:  0.209
# Epoch   0 Batch  479/538 - Train Accuracy:  0.823, Validation Accuracy:  0.789, Loss:  0.197
# Epoch   0 Batch  480/538 - Train Accuracy:  0.815, Validation Accuracy:  0.782, Loss:  0.216
# Epoch   0 Batch  481/538 - Train Accuracy:  0.786, Validation Accuracy:  0.782, Loss:  0.209
# Epoch   0 Batch  482/538 - Train Accuracy:  0.794, Validation Accuracy:  0.780, Loss:  0.199
# Epoch   0 Batch  483/538 - Train Accuracy:  0.777, Validation Accuracy:  0.781, Loss:  0.218
# Epoch   0 Batch  484/538 - Train Accuracy:  0.796, Validation Accuracy:  0.808, Loss:  0.215
# Epoch   0 Batch  485/538 - Train Accuracy:  0.795, Validation Accuracy:  0.798, Loss:  0.200
# Epoch   0 Batch  486/538 - Train Accuracy:  0.790, Validation Accuracy:  0.785, Loss:  0.210
# Epoch   0 Batch  487/538 - Train Accuracy:  0.814, Validation Accuracy:  0.792, Loss:  0.201
# Epoch   0 Batch  488/538 - Train Accuracy:  0.807, Validation Accuracy:  0.799, Loss:  0.194
# Epoch   0 Batch  489/538 - Train Accuracy:  0.790, Validation Accuracy:  0.818, Loss:  0.226
# Epoch   0 Batch  490/538 - Train Accuracy:  0.813, Validation Accuracy:  0.820, Loss:  0.205
# Epoch   0 Batch  491/538 - Train Accuracy:  0.759, Validation Accuracy:  0.804, Loss:  0.217
# Epoch   0 Batch  492/538 - Train Accuracy:  0.806, Validation Accuracy:  0.822, Loss:  0.201
# Epoch   0 Batch  493/538 - Train Accuracy:  0.797, Validation Accuracy:  0.823, Loss:  0.205
# Epoch   0 Batch  494/538 - Train Accuracy:  0.792, Validation Accuracy:  0.812, Loss:  0.208
# Epoch   0 Batch  495/538 - Train Accuracy:  0.801, Validation Accuracy:  0.807, Loss:  0.204
# Epoch   0 Batch  496/538 - Train Accuracy:  0.834, Validation Accuracy:  0.798, Loss:  0.190
# Epoch   0 Batch  497/538 - Train Accuracy:  0.846, Validation Accuracy:  0.804, Loss:  0.179
# Epoch   0 Batch  498/538 - Train Accuracy:  0.804, Validation Accuracy:  0.797, Loss:  0.214
# Epoch   0 Batch  499/538 - Train Accuracy:  0.823, Validation Accuracy:  0.791, Loss:  0.180
# Epoch   0 Batch  500/538 - Train Accuracy:  0.825, Validation Accuracy:  0.781, Loss:  0.177
# Epoch   0 Batch  501/538 - Train Accuracy:  0.842, Validation Accuracy:  0.787, Loss:  0.194
# Epoch   0 Batch  502/538 - Train Accuracy:  0.799, Validation Accuracy:  0.788, Loss:  0.192
# Epoch   0 Batch  503/538 - Train Accuracy:  0.836, Validation Accuracy:  0.791, Loss:  0.190
# Epoch   0 Batch  504/538 - Train Accuracy:  0.822, Validation Accuracy:  0.771, Loss:  0.185
# Epoch   0 Batch  505/538 - Train Accuracy:  0.812, Validation Accuracy:  0.794, Loss:  0.196
# Epoch   0 Batch  506/538 - Train Accuracy:  0.807, Validation Accuracy:  0.802, Loss:  0.208
# Epoch   0 Batch  507/538 - Train Accuracy:  0.779, Validation Accuracy:  0.803, Loss:  0.201
# Epoch   0 Batch  508/538 - Train Accuracy:  0.812, Validation Accuracy:  0.811, Loss:  0.181
# Epoch   0 Batch  509/538 - Train Accuracy:  0.823, Validation Accuracy:  0.789, Loss:  0.198
# Epoch   0 Batch  510/538 - Train Accuracy:  0.811, Validation Accuracy:  0.792, Loss:  0.198
# Epoch   0 Batch  511/538 - Train Accuracy:  0.816, Validation Accuracy:  0.795, Loss:  0.179
# Epoch   0 Batch  512/538 - Train Accuracy:  0.825, Validation Accuracy:  0.806, Loss:  0.186
# Epoch   0 Batch  513/538 - Train Accuracy:  0.800, Validation Accuracy:  0.819, Loss:  0.189
# Epoch   0 Batch  514/538 - Train Accuracy:  0.808, Validation Accuracy:  0.808, Loss:  0.188
# Epoch   0 Batch  515/538 - Train Accuracy:  0.820, Validation Accuracy:  0.808, Loss:  0.194
# ...
# Epoch   2 Batch  366/538 - Train Accuracy:  0.939, Validation Accuracy:  0.935, Loss:  0.042
# Epoch   2 Batch  367/538 - Train Accuracy:  0.946, Validation Accuracy:  0.924, Loss:  0.035
# Epoch   2 Batch  368/538 - Train Accuracy:  0.964, Validation Accuracy:  0.921, Loss:  0.027
# Epoch   2 Batch  369/538 - Train Accuracy:  0.953, Validation Accuracy:  0.921, Loss:  0.036
# Epoch   2 Batch  370/538 - Train Accuracy:  0.950, Validation Accuracy:  0.926, Loss:  0.038
# Epoch   2 Batch  371/538 - Train Accuracy:  0.966, Validation Accuracy:  0.932, Loss:  0.032
# Epoch   2 Batch  372/538 - Train Accuracy:  0.964, Validation Accuracy:  0.926, Loss:  0.034
# Epoch   2 Batch  373/538 - Train Accuracy:  0.949, Validation Accuracy:  0.927, Loss:  0.036
# Epoch   2 Batch  374/538 - Train Accuracy:  0.944, Validation Accuracy:  0.932, Loss:  0.032
# Epoch   2 Batch  375/538 - Train Accuracy:  0.963, Validation Accuracy:  0.934, Loss:  0.032
# Epoch   2 Batch  376/538 - Train Accuracy:  0.941, Validation Accuracy:  0.940, Loss:  0.037
# Epoch   2 Batch  377/538 - Train Accuracy:  0.939, Validation Accuracy:  0.940, Loss:  0.042
# Epoch   2 Batch  378/538 - Train Accuracy:  0.961, Validation Accuracy:  0.942, Loss:  0.031
# Epoch   2 Batch  379/538 - Train Accuracy:  0.941, Validation Accuracy:  0.933, Loss:  0.036
# Epoch   2 Batch  380/538 - Train Accuracy:  0.953, Validation Accuracy:  0.931, Loss:  0.037
# Epoch   2 Batch  381/538 - Train Accuracy:  0.963, Validation Accuracy:  0.929, Loss:  0.034
# Epoch   2 Batch  382/538 - Train Accuracy:  0.950, Validation Accuracy:  0.927, Loss:  0.040
# Epoch   2 Batch  383/538 - Train Accuracy:  0.969, Validation Accuracy:  0.931, Loss:  0.031
# Epoch   2 Batch  384/538 - Train Accuracy:  0.937, Validation Accuracy:  0.926, Loss:  0.041
# Epoch   2 Batch  385/538 - Train Accuracy:  0.959, Validation Accuracy:  0.926, Loss:  0.033
# Epoch   2 Batch  386/538 - Train Accuracy:  0.943, Validation Accuracy:  0.929, Loss:  0.033
# Epoch   2 Batch  387/538 - Train Accuracy:  0.940, Validation Accuracy:  0.927, Loss:  0.035
# Epoch   2 Batch  388/538 - Train Accuracy:  0.948, Validation Accuracy:  0.928, Loss:  0.033
# Epoch   2 Batch  389/538 - Train Accuracy:  0.930, Validation Accuracy:  0.931, Loss:  0.043
# Epoch   2 Batch  390/538 - Train Accuracy:  0.937, Validation Accuracy:  0.924, Loss:  0.038
# Epoch   2 Batch  391/538 - Train Accuracy:  0.952, Validation Accuracy:  0.926, Loss:  0.034
# Epoch   2 Batch  392/538 - Train Accuracy:  0.945, Validation Accuracy:  0.928, Loss:  0.035
# Epoch   2 Batch  393/538 - Train Accuracy:  0.954, Validation Accuracy:  0.925, Loss:  0.030
# Epoch   2 Batch  394/538 - Train Accuracy:  0.938, Validation Accuracy:  0.925, Loss:  0.047
# Epoch   2 Batch  395/538 - Train Accuracy:  0.936, Validation Accuracy:  0.936, Loss:  0.038
# Epoch   2 Batch  396/538 - Train Accuracy:  0.956, Validation Accuracy:  0.933, Loss:  0.033
# Epoch   2 Batch  397/538 - Train Accuracy:  0.948, Validation Accuracy:  0.932, Loss:  0.039
# Epoch   2 Batch  398/538 - Train Accuracy:  0.940, Validation Accuracy:  0.931, Loss:  0.038
# Epoch   2 Batch  399/538 - Train Accuracy:  0.941, Validation Accuracy:  0.931, Loss:  0.040
# Epoch   2 Batch  400/538 - Train Accuracy:  0.924, Validation Accuracy:  0.938, Loss:  0.046
# Epoch   2 Batch  401/538 - Train Accuracy:  0.966, Validation Accuracy:  0.937, Loss:  0.034
# Epoch   2 Batch  402/538 - Train Accuracy:  0.960, Validation Accuracy:  0.928, Loss:  0.030
# Epoch   2 Batch  403/538 - Train Accuracy:  0.952, Validation Accuracy:  0.923, Loss:  0.038
# Epoch   2 Batch  404/538 - Train Accuracy:  0.959, Validation Accuracy:  0.927, Loss:  0.038
# Epoch   2 Batch  405/538 - Train Accuracy:  0.945, Validation Accuracy:  0.930, Loss:  0.038
# Epoch   2 Batch  406/538 - Train Accuracy:  0.944, Validation Accuracy:  0.943, Loss:  0.036
# Epoch   2 Batch  407/538 - Train Accuracy:  0.967, Validation Accuracy:  0.938, Loss:  0.037
# Epoch   2 Batch  408/538 - Train Accuracy:  0.948, Validation Accuracy:  0.934, Loss:  0.034
# Epoch   2 Batch  409/538 - Train Accuracy:  0.956, Validation Accuracy:  0.933, Loss:  0.038
# Epoch   2 Batch  410/538 - Train Accuracy:  0.955, Validation Accuracy:  0.934, Loss:  0.035
# Epoch   2 Batch  411/538 - Train Accuracy:  0.956, Validation Accuracy:  0.928, Loss:  0.042
# Epoch   2 Batch  412/538 - Train Accuracy:  0.956, Validation Accuracy:  0.922, Loss:  0.031
# Epoch   2 Batch  413/538 - Train Accuracy:  0.958, Validation Accuracy:  0.922, Loss:  0.034
# Epoch   2 Batch  414/538 - Train Accuracy:  0.914, Validation Accuracy:  0.934, Loss:  0.045
# Epoch   2 Batch  415/538 - Train Accuracy:  0.945, Validation Accuracy:  0.941, Loss:  0.038
# Epoch   2 Batch  416/538 - Train Accuracy:  0.939, Validation Accuracy:  0.942, Loss:  0.037
# Epoch   2 Batch  417/538 - Train Accuracy:  0.955, Validation Accuracy:  0.942, Loss:  0.029
# Epoch   2 Batch  418/538 - Train Accuracy:  0.945, Validation Accuracy:  0.939, Loss:  0.039
# Epoch   2 Batch  419/538 - Train Accuracy:  0.959, Validation Accuracy:  0.948, Loss:  0.036
# Epoch   2 Batch  420/538 - Train Accuracy:  0.958, Validation Accuracy:  0.945, Loss:  0.035
# Epoch   2 Batch  421/538 - Train Accuracy:  0.945, Validation Accuracy:  0.934, Loss:  0.037
# Epoch   2 Batch  422/538 - Train Accuracy:  0.946, Validation Accuracy:  0.924, Loss:  0.037
# Epoch   2 Batch  423/538 - Train Accuracy:  0.961, Validation Accuracy:  0.925, Loss:  0.037
# Epoch   2 Batch  424/538 - Train Accuracy:  0.948, Validation Accuracy:  0.929, Loss:  0.042
# Epoch   2 Batch  425/538 - Train Accuracy:  0.936, Validation Accuracy:  0.932, Loss:  0.044
# Epoch   2 Batch  426/538 - Train Accuracy:  0.940, Validation Accuracy:  0.928, Loss:  0.038
# Epoch   2 Batch  427/538 - Train Accuracy:  0.938, Validation Accuracy:  0.940, Loss:  0.040
# Epoch   2 Batch  428/538 - Train Accuracy:  0.965, Validation Accuracy:  0.935, Loss:  0.029
# Epoch   2 Batch  429/538 - Train Accuracy:  0.951, Validation Accuracy:  0.929, Loss:  0.034
# Epoch   2 Batch  430/538 - Train Accuracy:  0.938, Validation Accuracy:  0.938, Loss:  0.040
# Epoch   2 Batch  431/538 - Train Accuracy:  0.960, Validation Accuracy:  0.934, Loss:  0.032
# Epoch   2 Batch  432/538 - Train Accuracy:  0.942, Validation Accuracy:  0.936, Loss:  0.037
# Epoch   2 Batch  433/538 - Train Accuracy:  0.947, Validation Accuracy:  0.937, Loss:  0.051
# Epoch   2 Batch  434/538 - Train Accuracy:  0.938, Validation Accuracy:  0.929, Loss:  0.038
# Epoch   2 Batch  435/538 - Train Accuracy:  0.947, Validation Accuracy:  0.928, Loss:  0.036
# Epoch   2 Batch  436/538 - Train Accuracy:  0.934, Validation Accuracy:  0.925, Loss:  0.040
# Epoch   2 Batch  437/538 - Train Accuracy:  0.962, Validation Accuracy:  0.929, Loss:  0.035
# Epoch   2 Batch  438/538 - Train Accuracy:  0.954, Validation Accuracy:  0.939, Loss:  0.029
# Epoch   2 Batch  439/538 - Train Accuracy:  0.959, Validation Accuracy:  0.941, Loss:  0.032
# Epoch   2 Batch  440/538 - Train Accuracy:  0.947, Validation Accuracy:  0.943, Loss:  0.038
# Epoch   2 Batch  441/538 - Train Accuracy:  0.946, Validation Accuracy:  0.940, Loss:  0.040
# Epoch   2 Batch  442/538 - Train Accuracy:  0.950, Validation Accuracy:  0.940, Loss:  0.033
# Epoch   2 Batch  443/538 - Train Accuracy:  0.947, Validation Accuracy:  0.939, Loss:  0.041
# Epoch   2 Batch  444/538 - Train Accuracy:  0.947, Validation Accuracy:  0.932, Loss:  0.033
# Epoch   2 Batch  445/538 - Train Accuracy:  0.955, Validation Accuracy:  0.932, Loss:  0.032
# Epoch   2 Batch  446/538 - Train Accuracy:  0.948, Validation Accuracy:  0.931, Loss:  0.031
# Epoch   2 Batch  447/538 - Train Accuracy:  0.934, Validation Accuracy:  0.937, Loss:  0.035
# Epoch   2 Batch  448/538 - Train Accuracy:  0.939, Validation Accuracy:  0.955, Loss:  0.033
# Epoch   2 Batch  449/538 - Train Accuracy:  0.962, Validation Accuracy:  0.948, Loss:  0.034
# Epoch   2 Batch  450/538 - Train Accuracy:  0.922, Validation Accuracy:  0.944, Loss:  0.044
# Epoch   2 Batch  451/538 - Train Accuracy:  0.950, Validation Accuracy:  0.948, Loss:  0.032
# Epoch   2 Batch  452/538 - Train Accuracy:  0.942, Validation Accuracy:  0.934, Loss:  0.035
# Epoch   2 Batch  453/538 - Train Accuracy:  0.940, Validation Accuracy:  0.937, Loss:  0.044
# Epoch   2 Batch  454/538 - Train Accuracy:  0.942, Validation Accuracy:  0.943, Loss:  0.037
# Epoch   2 Batch  455/538 - Train Accuracy:  0.962, Validation Accuracy:  0.950, Loss:  0.030
# Epoch   2 Batch  456/538 - Train Accuracy:  0.951, Validation Accuracy:  0.949, Loss:  0.044
# Epoch   2 Batch  457/538 - Train Accuracy:  0.942, Validation Accuracy:  0.945, Loss:  0.034
# Epoch   2 Batch  458/538 - Train Accuracy:  0.947, Validation Accuracy:  0.948, Loss:  0.036
# Epoch   2 Batch  459/538 - Train Accuracy:  0.955, Validation Accuracy:  0.949, Loss:  0.032
# Epoch   2 Batch  460/538 - Train Accuracy:  0.935, Validation Accuracy:  0.951, Loss:  0.035
# Epoch   2 Batch  461/538 - Train Accuracy:  0.959, Validation Accuracy:  0.940, Loss:  0.038
# Epoch   2 Batch  462/538 - Train Accuracy:  0.948, Validation Accuracy:  0.929, Loss:  0.037
# Epoch   2 Batch  463/538 - Train Accuracy:  0.935, Validation Accuracy:  0.930, Loss:  0.041
# Epoch   2 Batch  464/538 - Train Accuracy:  0.958, Validation Accuracy:  0.937, Loss:  0.036
# Epoch   2 Batch  465/538 - Train Accuracy:  0.960, Validation Accuracy:  0.944, Loss:  0.032
# Epoch   2 Batch  466/538 - Train Accuracy:  0.949, Validation Accuracy:  0.955, Loss:  0.034
# Epoch   2 Batch  467/538 - Train Accuracy:  0.950, Validation Accuracy:  0.950, Loss:  0.038
# Epoch   2 Batch  468/538 - Train Accuracy:  0.950, Validation Accuracy:  0.949, Loss:  0.045
# Epoch   2 Batch  469/538 - Train Accuracy:  0.947, Validation Accuracy:  0.951, Loss:  0.040
# Epoch   2 Batch  470/538 - Train Accuracy:  0.955, Validation Accuracy:  0.952, Loss:  0.032
# Epoch   2 Batch  471/538 - Train Accuracy:  0.957, Validation Accuracy:  0.942, Loss:  0.031
# Epoch   2 Batch  472/538 - Train Accuracy:  0.983, Validation Accuracy:  0.934, Loss:  0.028
# Epoch   2 Batch  473/538 - Train Accuracy:  0.940, Validation Accuracy:  0.935, Loss:  0.037
# Epoch   2 Batch  474/538 - Train Accuracy:  0.952, Validation Accuracy:  0.941, Loss:  0.034
# Epoch   2 Batch  475/538 - Train Accuracy:  0.958, Validation Accuracy:  0.947, Loss:  0.032
# Epoch   2 Batch  476/538 - Train Accuracy:  0.950, Validation Accuracy:  0.961, Loss:  0.033
# Epoch   2 Batch  477/538 - Train Accuracy:  0.947, Validation Accuracy:  0.956, Loss:  0.039
# Epoch   2 Batch  478/538 - Train Accuracy:  0.959, Validation Accuracy:  0.955, Loss:  0.029
# Epoch   2 Batch  479/538 - Train Accuracy:  0.949, Validation Accuracy:  0.957, Loss:  0.035
# Epoch   2 Batch  480/538 - Train Accuracy:  0.938, Validation Accuracy:  0.944, Loss:  0.037
# Epoch   2 Batch  481/538 - Train Accuracy:  0.945, Validation Accuracy:  0.938, Loss:  0.035
# Epoch   2 Batch  482/538 - Train Accuracy:  0.944, Validation Accuracy:  0.944, Loss:  0.031
# Epoch   2 Batch  483/538 - Train Accuracy:  0.941, Validation Accuracy:  0.945, Loss:  0.036
# Epoch   2 Batch  484/538 - Train Accuracy:  0.940, Validation Accuracy:  0.949, Loss:  0.037
# Epoch   2 Batch  485/538 - Train Accuracy:  0.953, Validation Accuracy:  0.939, Loss:  0.034
# Epoch   2 Batch  486/538 - Train Accuracy:  0.966, Validation Accuracy:  0.946, Loss:  0.027
# Epoch   2 Batch  487/538 - Train Accuracy:  0.953, Validation Accuracy:  0.952, Loss:  0.031
# Epoch   2 Batch  488/538 - Train Accuracy:  0.958, Validation Accuracy:  0.955, Loss:  0.028
# Epoch   2 Batch  489/538 - Train Accuracy:  0.949, Validation Accuracy:  0.947, Loss:  0.034
# Epoch   2 Batch  490/538 - Train Accuracy:  0.948, Validation Accuracy:  0.938, Loss:  0.036
# Epoch   2 Batch  491/538 - Train Accuracy:  0.937, Validation Accuracy:  0.940, Loss:  0.037
# Epoch   2 Batch  492/538 - Train Accuracy:  0.953, Validation Accuracy:  0.946, Loss:  0.034
# Epoch   2 Batch  493/538 - Train Accuracy:  0.945, Validation Accuracy:  0.959, Loss:  0.036
# Epoch   2 Batch  494/538 - Train Accuracy:  0.952, Validation Accuracy:  0.941, Loss:  0.034
# Epoch   2 Batch  495/538 - Train Accuracy:  0.943, Validation Accuracy:  0.934, Loss:  0.035
# Epoch   2 Batch  496/538 - Train Accuracy:  0.953, Validation Accuracy:  0.937, Loss:  0.032
# Epoch   2 Batch  497/538 - Train Accuracy:  0.951, Validation Accuracy:  0.940, Loss:  0.032
# Epoch   2 Batch  498/538 - Train Accuracy:  0.952, Validation Accuracy:  0.935, Loss:  0.033
# Epoch   2 Batch  499/538 - Train Accuracy:  0.954, Validation Accuracy:  0.943, Loss:  0.035
# Epoch   2 Batch  500/538 - Train Accuracy:  0.964, Validation Accuracy:  0.939, Loss:  0.025
# Epoch   2 Batch  501/538 - Train Accuracy:  0.965, Validation Accuracy:  0.953, Loss:  0.036
# Epoch   2 Batch  502/538 - Train Accuracy:  0.951, Validation Accuracy:  0.956, Loss:  0.036
# Epoch   2 Batch  503/538 - Train Accuracy:  0.960, Validation Accuracy:  0.952, Loss:  0.037
# Epoch   2 Batch  504/538 - Train Accuracy:  0.968, Validation Accuracy:  0.953, Loss:  0.032
# Epoch   2 Batch  505/538 - Train Accuracy:  0.951, Validation Accuracy:  0.953, Loss:  0.023
# Epoch   2 Batch  506/538 - Train Accuracy:  0.950, Validation Accuracy:  0.943, Loss:  0.032
# Epoch   2 Batch  507/538 - Train Accuracy:  0.946, Validation Accuracy:  0.933, Loss:  0.041
# Epoch   2 Batch  508/538 - Train Accuracy:  0.951, Validation Accuracy:  0.933, Loss:  0.031
# Epoch   2 Batch  509/538 - Train Accuracy:  0.946, Validation Accuracy:  0.933, Loss:  0.038
# Epoch   2 Batch  510/538 - Train Accuracy:  0.955, Validation Accuracy:  0.935, Loss:  0.031
# Epoch   2 Batch  511/538 - Train Accuracy:  0.953, Validation Accuracy:  0.936, Loss:  0.035
# Epoch   2 Batch  512/538 - Train Accuracy:  0.949, Validation Accuracy:  0.939, Loss:  0.035
# Epoch   2 Batch  513/538 - Train Accuracy:  0.922, Validation Accuracy:  0.942, Loss:  0.040
# Epoch   2 Batch  514/538 - Train Accuracy:  0.953, Validation Accuracy:  0.945, Loss:  0.033
# Epoch   2 Batch  515/538 - Train Accuracy:  0.956, Validation Accuracy:  0.949, Loss:  0.038
# Epoch   2 Batch  516/538 - Train Accuracy:  0.923, Validation Accuracy:  0.936, Loss:  0.038
# Epoch   2 Batch  517/538 - Train Accuracy:  0.955, Validation Accuracy:  0.928, Loss:  0.029
# Epoch   2 Batch  518/538 - Train Accuracy:  0.953, Validation Accuracy:  0.926, Loss:  0.033
# Epoch   2 Batch  519/538 - Train Accuracy:  0.968, Validation Accuracy:  0.922, Loss:  0.034
# Epoch   2 Batch  520/538 - Train Accuracy:  0.948, Validation Accuracy:  0.924, Loss:  0.032
# Epoch   2 Batch  521/538 - Train Accuracy:  0.956, Validation Accuracy:  0.932, Loss:  0.036
# Epoch   2 Batch  522/538 - Train Accuracy:  0.947, Validation Accuracy:  0.937, Loss:  0.032
# Epoch   2 Batch  523/538 - Train Accuracy:  0.960, Validation Accuracy:  0.947, Loss:  0.035
# Epoch   2 Batch  524/538 - Train Accuracy:  0.950, Validation Accuracy:  0.950, Loss:  0.030
# Epoch   2 Batch  525/538 - Train Accuracy:  0.959, Validation Accuracy:  0.944, Loss:  0.029
# Epoch   2 Batch  526/538 - Train Accuracy:  0.948, Validation Accuracy:  0.938, Loss:  0.033
# Epoch   2 Batch  527/538 - Train Accuracy:  0.951, Validation Accuracy:  0.939, Loss:  0.033
# Epoch   2 Batch  528/538 - Train Accuracy:  0.951, Validation Accuracy:  0.944, Loss:  0.039
# Epoch   2 Batch  529/538 - Train Accuracy:  0.937, Validation Accuracy:  0.946, Loss:  0.035
# Epoch   2 Batch  530/538 - Train Accuracy:  0.944, Validation Accuracy:  0.937, Loss:  0.037
# Epoch   2 Batch  531/538 - Train Accuracy:  0.938, Validation Accuracy:  0.930, Loss:  0.039
# Epoch   2 Batch  532/538 - Train Accuracy:  0.945, Validation Accuracy:  0.937, Loss:  0.034
# Epoch   2 Batch  533/538 - Train Accuracy:  0.949, Validation Accuracy:  0.946, Loss:  0.033
# Epoch   2 Batch  534/538 - Train Accuracy:  0.943, Validation Accuracy:  0.945, Loss:  0.032
# Epoch   2 Batch  535/538 - Train Accuracy:  0.949, Validation Accuracy:  0.940, Loss:  0.029
# Epoch   2 Batch  536/538 - Train Accuracy:  0.961, Validation Accuracy:  0.941, Loss:  0.035
# Model Trained and Saved

# %% [markdown]
# ### 保存参数
#
# 保存 `batch_size` 和 `save_path` 参数以进行推论（for inference）。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # 检查点

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## 句子到序列
#
# 要向模型提供要翻译的句子，你首先需要预处理该句子。实现函数 `sentence_to_seq()` 以预处理新的句子。
#
# - 将句子转换为小写形式
# - 使用 `vocab_to_int` 将单词转换为 id
#  - 如果单词不在词汇表中，将其转换为`<UNK>` 单词 id

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    sentence = sentence.lower()
    sentence = sentence.split(" ")
    default = "<UNK>"
    
    word_ids = [vocab_to_int.get(i, vocab_to_int[default]) for i in sentence]
    
    return word_ids

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## 翻译
#
# 将 `translate_sentence` 从英语翻译成法语。

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [33, 185, 213, 36, 5, 78, 172]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [88, 340, 29, 323, 179, 211, 121, 324, 1]
#   French Words: ['il', 'a', 'vu', 'un', 'vieux', 'camion', 'rouge', '.', '<EOS>']

# %% [markdown]
# ## 不完美的翻译
#
# 你可能注意到了，某些句子的翻译质量比其他的要好。因为你使用的数据集只有 227 个英语单词，但实际生活中有数千个单词，只有使用这些单词的句子结果才会比较理想。对于此项目，不需要达到完美的翻译。但是，如果你想创建更好的翻译模型，则需要更好的数据。
#
# 你可以使用 [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar) 语料库训练模型。该数据集拥有更多的词汇，讨论的话题也更丰富。但是，训练时间要好多天的时间，所以确保你有 GPU 并且对于我们提供的数据集，你的神经网络性能很棒。提交此项目后，别忘了研究下 WMT10 语料库。
#
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。保存记事本文件为 “dlnd_language_translation.ipynb”，再通过菜单中的“文件” ->“下载为”将其另存为 HTML 格式。提交的项目文档中需包含“helper.py”和“problem_unittests.py”文件。
